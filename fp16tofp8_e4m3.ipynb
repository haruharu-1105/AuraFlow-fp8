# %% [markdown]
# # convert fp16→fp8  float8_e4m3
# 量子化するスクリプトファイルです。
# Googleドライブをモデルファイルの保存先に使用します。実行時にアクセス許可を行ってください。
#
# ## 操作手順
# 1, メニューの「ランタイム」より「ランタイムのタイプを変更」し、ハードウェア アクセラレータ を「GPU」または「TPUv2」を選択してください。
# 2, 全てのセルを実行してください。(Ctrl+F9)

# %%
#@title fp8変換ツール(float8_e4m3)
repo_id = "fal/AuraFlow-v0.3" #@param {type:"string"}
repo_filename = "aura_flow_0.3.safetensors" #@param {type:"string"}
save_dir = "/content/drive/MyDrive/ComfyUI/models/checkpoints" #@param {type:"string"}
save_filename = "aura_flow_0.3-fp8.safetensors" #@param {type:"string"}
is_debug = True #@param {type:"boolean"}

# 量子化を行わないレイヤー
non_quantized_layers = set(["vae.",
                            "model.double_layers.",
                            "model.single_layers.31"])

import json
from pathlib import Path
import time

from google.colab import drive, runtime
from safetensors.torch import load_file, save_file
import torch
from tqdm import tqdm
from huggingface_hub import hf_hub_download


def mount_drive(path: str):
  if path.startswith('/content/drive'):
    print("Google Driveをマウントしています。")
    drive.mount('/content/drive', force_remount=True)


def read_safetensors_metadata(file: str):
  """read safetensors metadata"""
  with open(file, 'rb') as f:
    header_size = int.from_bytes(f.read(8), 'little')
    header_json = f.read(header_size).decode('utf-8')
    header = json.loads(header_json)
    metadata = header.get('__metadata__', {})
    return metadata


try:
  # Googleドライブのマウント処理を行います。
  mount_drive(save_dir)
  # Repositoryからモデルファイルのダウンロードを行います。
  download_file = hf_hub_download(repo_id=repo_id, filename=repo_filename, revision="main")
  output_path : Path  = Path(save_dir) / save_filename
  output_path.parent.mkdir(parents=True, exist_ok=True)

  # メタ情報を読み取ります。
  metadata = read_safetensors_metadata(download_file)
  print(json.dumps(metadata, indent=4)) #show metadata

  sd_pruned = dict() #initialize empty dict
  layer_status = [] # レイヤー名とスキップ有無を保存するリスト
  state_dict = load_file(download_file) #load safetensors file
  # fp8化を行います。
  for key in tqdm(state_dict): #for each key in the safetensors file
    layer_name = str(key)
    # layer_nameがnon_quantized_layers内のいずれかのプレフィックスで始まるかをチェック
    if any(layer_name.startswith(skip_layer) for skip_layer in non_quantized_layers):
        sd_pruned[key] = state_dict[key]
        layer_status.append((layer_name, "スキップ"))  # スキップされた場合
        continue  # スキップする場合は次へ

    sd_pruned[key] = state_dict[key].to(torch.float8_e4m3fn)
    layer_status.append((layer_name, "処理済み"))  # スキップされなかった場合

  if is_debug:
    # レイヤー名とスキップの有無を出力
    for layer_name, status in layer_status:
      print(f"{layer_name}, {status}")

  #save_file(sd_pruned, output_path, metadata={"format": "pt", **metadata})
  print(download_file)
  print("ファイルを保存しました。Googleドライブ内の以下のフォルダを確認してください。")
  print(output_path)
finally:
    print("5秒後にランタイムの接続を解除します。")
    time.sleep(5)
    runtime.unassign()
# Out:
# Google Driveをマウントしています。
# Mounted at /content/drive
# {}
# 100%|██████████| 824/824 [01:11<00:00, 11.48it/s]
# model.cond_seq_linear.weight, 処理済み
# model.double_layers.0.attn.w1k.weight, スキップ
# model.double_layers.0.attn.w1o.weight, スキップ
# model.double_layers.0.attn.w1q.weight, スキップ
# model.double_layers.0.attn.w1v.weight, スキップ
# model.double_layers.0.attn.w2k.weight, スキップ
# model.double_layers.0.attn.w2o.weight, スキップ
# model.double_layers.0.attn.w2q.weight, スキップ
# model.double_layers.0.attn.w2v.weight, スキップ
# model.double_layers.0.mlpC.c_fc1.weight, スキップ
# model.double_layers.0.mlpC.c_fc2.weight, スキップ
# model.double_layers.0.mlpC.c_proj.weight, スキップ
# model.double_layers.0.mlpX.c_fc1.weight, スキップ
# model.double_layers.0.mlpX.c_fc2.weight, スキップ
# model.double_layers.0.mlpX.c_proj.weight, スキップ
# model.double_layers.0.modC.1.weight, スキップ
# model.double_layers.0.modX.1.weight, スキップ
# model.double_layers.1.attn.w1k.weight, スキップ
# model.double_layers.1.attn.w1o.weight, スキップ
# model.double_layers.1.attn.w1q.weight, スキップ
# model.double_layers.1.attn.w1v.weight, スキップ
# model.double_layers.1.attn.w2k.weight, スキップ
# model.double_layers.1.attn.w2o.weight, スキップ
# model.double_layers.1.attn.w2q.weight, スキップ
# model.double_layers.1.attn.w2v.weight, スキップ
# model.double_layers.1.mlpC.c_fc1.weight, スキップ
# model.double_layers.1.mlpC.c_fc2.weight, スキップ
# model.double_layers.1.mlpC.c_proj.weight, スキップ
# model.double_layers.1.mlpX.c_fc1.weight, スキップ
# model.double_layers.1.mlpX.c_fc2.weight, スキップ
# model.double_layers.1.mlpX.c_proj.weight, スキップ
# model.double_layers.1.modC.1.weight, スキップ
# model.double_layers.1.modX.1.weight, スキップ
# model.double_layers.2.attn.w1k.weight, スキップ
# model.double_layers.2.attn.w1o.weight, スキップ
# model.double_layers.2.attn.w1q.weight, スキップ
# model.double_layers.2.attn.w1v.weight, スキップ
# model.double_layers.2.attn.w2k.weight, スキップ
# model.double_layers.2.attn.w2o.weight, スキップ
# model.double_layers.2.attn.w2q.weight, スキップ
# model.double_layers.2.attn.w2v.weight, スキップ
# model.double_layers.2.mlpC.c_fc1.weight, スキップ
# model.double_layers.2.mlpC.c_fc2.weight, スキップ
# model.double_layers.2.mlpC.c_proj.weight, スキップ
# model.double_layers.2.mlpX.c_fc1.weight, スキップ
# model.double_layers.2.mlpX.c_fc2.weight, スキップ
# model.double_layers.2.mlpX.c_proj.weight, スキップ
# model.double_layers.2.modC.1.weight, スキップ
# model.double_layers.2.modX.1.weight, スキップ
# model.double_layers.3.attn.w1k.weight, スキップ
# model.double_layers.3.attn.w1o.weight, スキップ
# model.double_layers.3.attn.w1q.weight, スキップ
# model.double_layers.3.attn.w1v.weight, スキップ
# model.double_layers.3.attn.w2k.weight, スキップ
# model.double_layers.3.attn.w2o.weight, スキップ
# model.double_layers.3.attn.w2q.weight, スキップ
# model.double_layers.3.attn.w2v.weight, スキップ
# model.double_layers.3.mlpC.c_fc1.weight, スキップ
# model.double_layers.3.mlpC.c_fc2.weight, スキップ
# model.double_layers.3.mlpC.c_proj.weight, スキップ
# model.double_layers.3.mlpX.c_fc1.weight, スキップ
# model.double_layers.3.mlpX.c_fc2.weight, スキップ
# model.double_layers.3.mlpX.c_proj.weight, スキップ
# model.double_layers.3.modC.1.weight, スキップ
# model.double_layers.3.modX.1.weight, スキップ
# model.final_linear.weight, 処理済み
# model.init_x_linear.bias, 処理済み
# model.init_x_linear.weight, 処理済み
# model.modF.1.weight, 処理済み
# model.positional_encoding, 処理済み
# model.register_tokens, 処理済み
# model.single_layers.0.attn.w1k.weight, 処理済み
# model.single_layers.0.attn.w1o.weight, 処理済み
# model.single_layers.0.attn.w1q.weight, 処理済み
# model.single_layers.0.attn.w1v.weight, 処理済み
# model.single_layers.0.mlp.c_fc1.weight, 処理済み
# model.single_layers.0.mlp.c_fc2.weight, 処理済み
# model.single_layers.0.mlp.c_proj.weight, 処理済み
# model.single_layers.0.modCX.1.weight, 処理済み
# model.single_layers.1.attn.w1k.weight, 処理済み
# model.single_layers.1.attn.w1o.weight, 処理済み
# model.single_layers.1.attn.w1q.weight, 処理済み
# model.single_layers.1.attn.w1v.weight, 処理済み
# model.single_layers.1.mlp.c_fc1.weight, 処理済み
# model.single_layers.1.mlp.c_fc2.weight, 処理済み
# model.single_layers.1.mlp.c_proj.weight, 処理済み
# model.single_layers.1.modCX.1.weight, 処理済み
# model.single_layers.10.attn.w1k.weight, 処理済み
# model.single_layers.10.attn.w1o.weight, 処理済み
# model.single_layers.10.attn.w1q.weight, 処理済み
# model.single_layers.10.attn.w1v.weight, 処理済み
# model.single_layers.10.mlp.c_fc1.weight, 処理済み
# model.single_layers.10.mlp.c_fc2.weight, 処理済み
# model.single_layers.10.mlp.c_proj.weight, 処理済み
# model.single_layers.10.modCX.1.weight, 処理済み
# model.single_layers.11.attn.w1k.weight, 処理済み
# model.single_layers.11.attn.w1o.weight, 処理済み
# model.single_layers.11.attn.w1q.weight, 処理済み
# model.single_layers.11.attn.w1v.weight, 処理済み
# model.single_layers.11.mlp.c_fc1.weight, 処理済み
# model.single_layers.11.mlp.c_fc2.weight, 処理済み
# model.single_layers.11.mlp.c_proj.weight, 処理済み
# model.single_layers.11.modCX.1.weight, 処理済み
# model.single_layers.12.attn.w1k.weight, 処理済み
# model.single_layers.12.attn.w1o.weight, 処理済み
# model.single_layers.12.attn.w1q.weight, 処理済み
# model.single_layers.12.attn.w1v.weight, 処理済み
# model.single_layers.12.mlp.c_fc1.weight, 処理済み
# model.single_layers.12.mlp.c_fc2.weight, 処理済み
# model.single_layers.12.mlp.c_proj.weight, 処理済み
# model.single_layers.12.modCX.1.weight, 処理済み
# model.single_layers.13.attn.w1k.weight, 処理済み
# model.single_layers.13.attn.w1o.weight, 処理済み
# model.single_layers.13.attn.w1q.weight, 処理済み
# model.single_layers.13.attn.w1v.weight, 処理済み
# model.single_layers.13.mlp.c_fc1.weight, 処理済み
# model.single_layers.13.mlp.c_fc2.weight, 処理済み
# model.single_layers.13.mlp.c_proj.weight, 処理済み
# model.single_layers.13.modCX.1.weight, 処理済み
# model.single_layers.14.attn.w1k.weight, 処理済み
# model.single_layers.14.attn.w1o.weight, 処理済み
# model.single_layers.14.attn.w1q.weight, 処理済み
# model.single_layers.14.attn.w1v.weight, 処理済み
# model.single_layers.14.mlp.c_fc1.weight, 処理済み
# model.single_layers.14.mlp.c_fc2.weight, 処理済み
# model.single_layers.14.mlp.c_proj.weight, 処理済み
# model.single_layers.14.modCX.1.weight, 処理済み
# model.single_layers.15.attn.w1k.weight, 処理済み
# model.single_layers.15.attn.w1o.weight, 処理済み
# model.single_layers.15.attn.w1q.weight, 処理済み
# model.single_layers.15.attn.w1v.weight, 処理済み
# model.single_layers.15.mlp.c_fc1.weight, 処理済み
# model.single_layers.15.mlp.c_fc2.weight, 処理済み
# model.single_layers.15.mlp.c_proj.weight, 処理済み
# model.single_layers.15.modCX.1.weight, 処理済み
# model.single_layers.16.attn.w1k.weight, 処理済み
# model.single_layers.16.attn.w1o.weight, 処理済み
# model.single_layers.16.attn.w1q.weight, 処理済み
# model.single_layers.16.attn.w1v.weight, 処理済み
# model.single_layers.16.mlp.c_fc1.weight, 処理済み
# model.single_layers.16.mlp.c_fc2.weight, 処理済み
# model.single_layers.16.mlp.c_proj.weight, 処理済み
# model.single_layers.16.modCX.1.weight, 処理済み
# model.single_layers.17.attn.w1k.weight, 処理済み
# model.single_layers.17.attn.w1o.weight, 処理済み
# model.single_layers.17.attn.w1q.weight, 処理済み
# model.single_layers.17.attn.w1v.weight, 処理済み
# model.single_layers.17.mlp.c_fc1.weight, 処理済み
# model.single_layers.17.mlp.c_fc2.weight, 処理済み
# model.single_layers.17.mlp.c_proj.weight, 処理済み
# model.single_layers.17.modCX.1.weight, 処理済み
# model.single_layers.18.attn.w1k.weight, 処理済み
# model.single_layers.18.attn.w1o.weight, 処理済み
# model.single_layers.18.attn.w1q.weight, 処理済み
# model.single_layers.18.attn.w1v.weight, 処理済み
# model.single_layers.18.mlp.c_fc1.weight, 処理済み
# model.single_layers.18.mlp.c_fc2.weight, 処理済み
# model.single_layers.18.mlp.c_proj.weight, 処理済み
# model.single_layers.18.modCX.1.weight, 処理済み
# model.single_layers.19.attn.w1k.weight, 処理済み
# model.single_layers.19.attn.w1o.weight, 処理済み
# model.single_layers.19.attn.w1q.weight, 処理済み
# model.single_layers.19.attn.w1v.weight, 処理済み
# model.single_layers.19.mlp.c_fc1.weight, 処理済み
# model.single_layers.19.mlp.c_fc2.weight, 処理済み
# model.single_layers.19.mlp.c_proj.weight, 処理済み
# model.single_layers.19.modCX.1.weight, 処理済み
# model.single_layers.2.attn.w1k.weight, 処理済み
# model.single_layers.2.attn.w1o.weight, 処理済み
# model.single_layers.2.attn.w1q.weight, 処理済み
# model.single_layers.2.attn.w1v.weight, 処理済み
# model.single_layers.2.mlp.c_fc1.weight, 処理済み
# model.single_layers.2.mlp.c_fc2.weight, 処理済み
# model.single_layers.2.mlp.c_proj.weight, 処理済み
# model.single_layers.2.modCX.1.weight, 処理済み
# model.single_layers.20.attn.w1k.weight, 処理済み
# model.single_layers.20.attn.w1o.weight, 処理済み
# model.single_layers.20.attn.w1q.weight, 処理済み
# model.single_layers.20.attn.w1v.weight, 処理済み
# model.single_layers.20.mlp.c_fc1.weight, 処理済み
# model.single_layers.20.mlp.c_fc2.weight, 処理済み
# model.single_layers.20.mlp.c_proj.weight, 処理済み
# model.single_layers.20.modCX.1.weight, 処理済み
# model.single_layers.21.attn.w1k.weight, 処理済み
# model.single_layers.21.attn.w1o.weight, 処理済み
# model.single_layers.21.attn.w1q.weight, 処理済み
# model.single_layers.21.attn.w1v.weight, 処理済み
# model.single_layers.21.mlp.c_fc1.weight, 処理済み
# model.single_layers.21.mlp.c_fc2.weight, 処理済み
# model.single_layers.21.mlp.c_proj.weight, 処理済み
# model.single_layers.21.modCX.1.weight, 処理済み
# model.single_layers.22.attn.w1k.weight, 処理済み
# model.single_layers.22.attn.w1o.weight, 処理済み
# model.single_layers.22.attn.w1q.weight, 処理済み
# model.single_layers.22.attn.w1v.weight, 処理済み
# model.single_layers.22.mlp.c_fc1.weight, 処理済み
# model.single_layers.22.mlp.c_fc2.weight, 処理済み
# model.single_layers.22.mlp.c_proj.weight, 処理済み
# model.single_layers.22.modCX.1.weight, 処理済み
# model.single_layers.23.attn.w1k.weight, 処理済み
# model.single_layers.23.attn.w1o.weight, 処理済み
# model.single_layers.23.attn.w1q.weight, 処理済み
# model.single_layers.23.attn.w1v.weight, 処理済み
# model.single_layers.23.mlp.c_fc1.weight, 処理済み
# model.single_layers.23.mlp.c_fc2.weight, 処理済み
# model.single_layers.23.mlp.c_proj.weight, 処理済み
# model.single_layers.23.modCX.1.weight, 処理済み
# model.single_layers.24.attn.w1k.weight, 処理済み
# model.single_layers.24.attn.w1o.weight, 処理済み
# model.single_layers.24.attn.w1q.weight, 処理済み
# model.single_layers.24.attn.w1v.weight, 処理済み
# model.single_layers.24.mlp.c_fc1.weight, 処理済み
# model.single_layers.24.mlp.c_fc2.weight, 処理済み
# model.single_layers.24.mlp.c_proj.weight, 処理済み
# model.single_layers.24.modCX.1.weight, 処理済み
# model.single_layers.25.attn.w1k.weight, 処理済み
# model.single_layers.25.attn.w1o.weight, 処理済み
# model.single_layers.25.attn.w1q.weight, 処理済み
# model.single_layers.25.attn.w1v.weight, 処理済み
# model.single_layers.25.mlp.c_fc1.weight, 処理済み
# model.single_layers.25.mlp.c_fc2.weight, 処理済み
# model.single_layers.25.mlp.c_proj.weight, 処理済み
# model.single_layers.25.modCX.1.weight, 処理済み
# model.single_layers.26.attn.w1k.weight, 処理済み
# model.single_layers.26.attn.w1o.weight, 処理済み
# model.single_layers.26.attn.w1q.weight, 処理済み
# model.single_layers.26.attn.w1v.weight, 処理済み
# model.single_layers.26.mlp.c_fc1.weight, 処理済み
# model.single_layers.26.mlp.c_fc2.weight, 処理済み
# model.single_layers.26.mlp.c_proj.weight, 処理済み
# model.single_layers.26.modCX.1.weight, 処理済み
# model.single_layers.27.attn.w1k.weight, 処理済み
# model.single_layers.27.attn.w1o.weight, 処理済み
# model.single_layers.27.attn.w1q.weight, 処理済み
# model.single_layers.27.attn.w1v.weight, 処理済み
# model.single_layers.27.mlp.c_fc1.weight, 処理済み
# model.single_layers.27.mlp.c_fc2.weight, 処理済み
# model.single_layers.27.mlp.c_proj.weight, 処理済み
# model.single_layers.27.modCX.1.weight, 処理済み
# model.single_layers.28.attn.w1k.weight, 処理済み
# model.single_layers.28.attn.w1o.weight, 処理済み
# model.single_layers.28.attn.w1q.weight, 処理済み
# model.single_layers.28.attn.w1v.weight, 処理済み
# model.single_layers.28.mlp.c_fc1.weight, 処理済み
# model.single_layers.28.mlp.c_fc2.weight, 処理済み
# model.single_layers.28.mlp.c_proj.weight, 処理済み
# model.single_layers.28.modCX.1.weight, 処理済み
# model.single_layers.29.attn.w1k.weight, 処理済み
# model.single_layers.29.attn.w1o.weight, 処理済み
# model.single_layers.29.attn.w1q.weight, 処理済み
# model.single_layers.29.attn.w1v.weight, 処理済み
# model.single_layers.29.mlp.c_fc1.weight, 処理済み
# model.single_layers.29.mlp.c_fc2.weight, 処理済み
# model.single_layers.29.mlp.c_proj.weight, 処理済み
# model.single_layers.29.modCX.1.weight, 処理済み
# model.single_layers.3.attn.w1k.weight, 処理済み
# model.single_layers.3.attn.w1o.weight, 処理済み
# model.single_layers.3.attn.w1q.weight, 処理済み
# model.single_layers.3.attn.w1v.weight, 処理済み
# model.single_layers.3.mlp.c_fc1.weight, 処理済み
# model.single_layers.3.mlp.c_fc2.weight, 処理済み
# model.single_layers.3.mlp.c_proj.weight, 処理済み
# model.single_layers.3.modCX.1.weight, 処理済み
# model.single_layers.30.attn.w1k.weight, 処理済み
# model.single_layers.30.attn.w1o.weight, 処理済み
# model.single_layers.30.attn.w1q.weight, 処理済み
# model.single_layers.30.attn.w1v.weight, 処理済み
# model.single_layers.30.mlp.c_fc1.weight, 処理済み
# model.single_layers.30.mlp.c_fc2.weight, 処理済み
# model.single_layers.30.mlp.c_proj.weight, 処理済み
# model.single_layers.30.modCX.1.weight, 処理済み
# model.single_layers.31.attn.w1k.weight, スキップ
# model.single_layers.31.attn.w1o.weight, スキップ
# model.single_layers.31.attn.w1q.weight, スキップ
# model.single_layers.31.attn.w1v.weight, スキップ
# model.single_layers.31.mlp.c_fc1.weight, スキップ
# model.single_layers.31.mlp.c_fc2.weight, スキップ
# model.single_layers.31.mlp.c_proj.weight, スキップ
# model.single_layers.31.modCX.1.weight, スキップ
# model.single_layers.4.attn.w1k.weight, 処理済み
# model.single_layers.4.attn.w1o.weight, 処理済み
# model.single_layers.4.attn.w1q.weight, 処理済み
# model.single_layers.4.attn.w1v.weight, 処理済み
# model.single_layers.4.mlp.c_fc1.weight, 処理済み
# model.single_layers.4.mlp.c_fc2.weight, 処理済み
# model.single_layers.4.mlp.c_proj.weight, 処理済み
# model.single_layers.4.modCX.1.weight, 処理済み
# model.single_layers.5.attn.w1k.weight, 処理済み
# model.single_layers.5.attn.w1o.weight, 処理済み
# model.single_layers.5.attn.w1q.weight, 処理済み
# model.single_layers.5.attn.w1v.weight, 処理済み
# model.single_layers.5.mlp.c_fc1.weight, 処理済み
# model.single_layers.5.mlp.c_fc2.weight, 処理済み
# model.single_layers.5.mlp.c_proj.weight, 処理済み
# model.single_layers.5.modCX.1.weight, 処理済み
# model.single_layers.6.attn.w1k.weight, 処理済み
# model.single_layers.6.attn.w1o.weight, 処理済み
# model.single_layers.6.attn.w1q.weight, 処理済み
# model.single_layers.6.attn.w1v.weight, 処理済み
# model.single_layers.6.mlp.c_fc1.weight, 処理済み
# model.single_layers.6.mlp.c_fc2.weight, 処理済み
# model.single_layers.6.mlp.c_proj.weight, 処理済み
# model.single_layers.6.modCX.1.weight, 処理済み
# model.single_layers.7.attn.w1k.weight, 処理済み
# model.single_layers.7.attn.w1o.weight, 処理済み
# model.single_layers.7.attn.w1q.weight, 処理済み
# model.single_layers.7.attn.w1v.weight, 処理済み
# model.single_layers.7.mlp.c_fc1.weight, 処理済み
# model.single_layers.7.mlp.c_fc2.weight, 処理済み
# model.single_layers.7.mlp.c_proj.weight, 処理済み
# model.single_layers.7.modCX.1.weight, 処理済み
# model.single_layers.8.attn.w1k.weight, 処理済み
# model.single_layers.8.attn.w1o.weight, 処理済み
# model.single_layers.8.attn.w1q.weight, 処理済み
# model.single_layers.8.attn.w1v.weight, 処理済み
# model.single_layers.8.mlp.c_fc1.weight, 処理済み
# model.single_layers.8.mlp.c_fc2.weight, 処理済み
# model.single_layers.8.mlp.c_proj.weight, 処理済み
# model.single_layers.8.modCX.1.weight, 処理済み
# model.single_layers.9.attn.w1k.weight, 処理済み
# model.single_layers.9.attn.w1o.weight, 処理済み
# model.single_layers.9.attn.w1q.weight, 処理済み
# model.single_layers.9.attn.w1v.weight, 処理済み
# model.single_layers.9.mlp.c_fc1.weight, 処理済み
# model.single_layers.9.mlp.c_fc2.weight, 処理済み
# model.single_layers.9.mlp.c_proj.weight, 処理済み
# model.single_layers.9.modCX.1.weight, 処理済み
# model.t_embedder.mlp.0.bias, 処理済み
# model.t_embedder.mlp.0.weight, 処理済み
# model.t_embedder.mlp.2.bias, 処理済み
# model.t_embedder.mlp.2.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.0.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.1.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.10.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.11.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.12.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.13.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.14.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.15.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.16.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.17.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.18.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.19.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.2.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.20.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.21.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.22.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.23.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.3.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.4.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.5.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.6.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.7.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.8.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.0.SelfAttention.k.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.0.SelfAttention.o.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.0.SelfAttention.q.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.0.SelfAttention.relative_attention_bias.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.0.SelfAttention.v.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.0.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.1.DenseReluDense.wi_0.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.1.DenseReluDense.wi_1.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.1.DenseReluDense.wo.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.block.9.layer.1.layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.embed_tokens.weight, 処理済み
# text_encoders.pile_t5xl.transformer.encoder.final_layer_norm.weight, 処理済み
# text_encoders.pile_t5xl.transformer.shared.weight, 処理済み
# vae.decoder.conv_in.bias, スキップ
# vae.decoder.conv_in.weight, スキップ
# vae.decoder.conv_out.bias, スキップ
# vae.decoder.conv_out.weight, スキップ
# vae.decoder.mid.attn_1.k.bias, スキップ
# vae.decoder.mid.attn_1.k.weight, スキップ
# vae.decoder.mid.attn_1.norm.bias, スキップ
# vae.decoder.mid.attn_1.norm.weight, スキップ
# vae.decoder.mid.attn_1.proj_out.bias, スキップ
# vae.decoder.mid.attn_1.proj_out.weight, スキップ
# vae.decoder.mid.attn_1.q.bias, スキップ
# vae.decoder.mid.attn_1.q.weight, スキップ
# vae.decoder.mid.attn_1.v.bias, スキップ
# vae.decoder.mid.attn_1.v.weight, スキップ
# vae.decoder.mid.block_1.conv1.bias, スキップ
# vae.decoder.mid.block_1.conv1.weight, スキップ
# vae.decoder.mid.block_1.conv2.bias, スキップ
# vae.decoder.mid.block_1.conv2.weight, スキップ
# vae.decoder.mid.block_1.norm1.bias, スキップ
# vae.decoder.mid.block_1.norm1.weight, スキップ
# vae.decoder.mid.block_1.norm2.bias, スキップ
# vae.decoder.mid.block_1.norm2.weight, スキップ
# vae.decoder.mid.block_2.conv1.bias, スキップ
# vae.decoder.mid.block_2.conv1.weight, スキップ
# vae.decoder.mid.block_2.conv2.bias, スキップ
# vae.decoder.mid.block_2.conv2.weight, スキップ
# vae.decoder.mid.block_2.norm1.bias, スキップ
# vae.decoder.mid.block_2.norm1.weight, スキップ
# vae.decoder.mid.block_2.norm2.bias, スキップ
# vae.decoder.mid.block_2.norm2.weight, スキップ
# vae.decoder.norm_out.bias, スキップ
# vae.decoder.norm_out.weight, スキップ
# vae.decoder.up.0.block.0.conv1.bias, スキップ
# vae.decoder.up.0.block.0.conv1.weight, スキップ
# vae.decoder.up.0.block.0.conv2.bias, スキップ
# vae.decoder.up.0.block.0.conv2.weight, スキップ
# vae.decoder.up.0.block.0.nin_shortcut.bias, スキップ
# vae.decoder.up.0.block.0.nin_shortcut.weight, スキップ
# vae.decoder.up.0.block.0.norm1.bias, スキップ
# vae.decoder.up.0.block.0.norm1.weight, スキップ
# vae.decoder.up.0.block.0.norm2.bias, スキップ
# vae.decoder.up.0.block.0.norm2.weight, スキップ
# vae.decoder.up.0.block.1.conv1.bias, スキップ
# vae.decoder.up.0.block.1.conv1.weight, スキップ
# vae.decoder.up.0.block.1.conv2.bias, スキップ
# vae.decoder.up.0.block.1.conv2.weight, スキップ
# vae.decoder.up.0.block.1.norm1.bias, スキップ
# vae.decoder.up.0.block.1.norm1.weight, スキップ
# vae.decoder.up.0.block.1.norm2.bias, スキップ
# vae.decoder.up.0.block.1.norm2.weight, スキップ
# vae.decoder.up.0.block.2.conv1.bias, スキップ
# vae.decoder.up.0.block.2.conv1.weight, スキップ
# vae.decoder.up.0.block.2.conv2.bias, スキップ
# vae.decoder.up.0.block.2.conv2.weight, スキップ
# vae.decoder.up.0.block.2.norm1.bias, スキップ
# vae.decoder.up.0.block.2.norm1.weight, スキップ
# vae.decoder.up.0.block.2.norm2.bias, スキップ
# vae.decoder.up.0.block.2.norm2.weight, スキップ
# vae.decoder.up.1.block.0.conv1.bias, スキップ
# vae.decoder.up.1.block.0.conv1.weight, スキップ
# vae.decoder.up.1.block.0.conv2.bias, スキップ
# vae.decoder.up.1.block.0.conv2.weight, スキップ
# vae.decoder.up.1.block.0.nin_shortcut.bias, スキップ
# vae.decoder.up.1.block.0.nin_shortcut.weight, スキップ
# vae.decoder.up.1.block.0.norm1.bias, スキップ
# vae.decoder.up.1.block.0.norm1.weight, スキップ
# vae.decoder.up.1.block.0.norm2.bias, スキップ
# vae.decoder.up.1.block.0.norm2.weight, スキップ
# vae.decoder.up.1.block.1.conv1.bias, スキップ
# vae.decoder.up.1.block.1.conv1.weight, スキップ
# vae.decoder.up.1.block.1.conv2.bias, スキップ
# vae.decoder.up.1.block.1.conv2.weight, スキップ
# vae.decoder.up.1.block.1.norm1.bias, スキップ
# vae.decoder.up.1.block.1.norm1.weight, スキップ
# vae.decoder.up.1.block.1.norm2.bias, スキップ
# vae.decoder.up.1.block.1.norm2.weight, スキップ
# vae.decoder.up.1.block.2.conv1.bias, スキップ
# vae.decoder.up.1.block.2.conv1.weight, スキップ
# vae.decoder.up.1.block.2.conv2.bias, スキップ
# vae.decoder.up.1.block.2.conv2.weight, スキップ
# vae.decoder.up.1.block.2.norm1.bias, スキップ
# vae.decoder.up.1.block.2.norm1.weight, スキップ
# vae.decoder.up.1.block.2.norm2.bias, スキップ
# vae.decoder.up.1.block.2.norm2.weight, スキップ
# vae.decoder.up.1.upsample.conv.bias, スキップ
# vae.decoder.up.1.upsample.conv.weight, スキップ
# vae.decoder.up.2.block.0.conv1.bias, スキップ
# vae.decoder.up.2.block.0.conv1.weight, スキップ
# vae.decoder.up.2.block.0.conv2.bias, スキップ
# vae.decoder.up.2.block.0.conv2.weight, スキップ
# vae.decoder.up.2.block.0.norm1.bias, スキップ
# vae.decoder.up.2.block.0.norm1.weight, スキップ
# vae.decoder.up.2.block.0.norm2.bias, スキップ
# vae.decoder.up.2.block.0.norm2.weight, スキップ
# vae.decoder.up.2.block.1.conv1.bias, スキップ
# vae.decoder.up.2.block.1.conv1.weight, スキップ
# vae.decoder.up.2.block.1.conv2.bias, スキップ
# vae.decoder.up.2.block.1.conv2.weight, スキップ
# vae.decoder.up.2.block.1.norm1.bias, スキップ
# vae.decoder.up.2.block.1.norm1.weight, スキップ
# vae.decoder.up.2.block.1.norm2.bias, スキップ
# vae.decoder.up.2.block.1.norm2.weight, スキップ
# vae.decoder.up.2.block.2.conv1.bias, スキップ
# vae.decoder.up.2.block.2.conv1.weight, スキップ
# vae.decoder.up.2.block.2.conv2.bias, スキップ
# vae.decoder.up.2.block.2.conv2.weight, スキップ
# vae.decoder.up.2.block.2.norm1.bias, スキップ
# vae.decoder.up.2.block.2.norm1.weight, スキップ
# vae.decoder.up.2.block.2.norm2.bias, スキップ
# vae.decoder.up.2.block.2.norm2.weight, スキップ
# vae.decoder.up.2.upsample.conv.bias, スキップ
# vae.decoder.up.2.upsample.conv.weight, スキップ
# vae.decoder.up.3.block.0.conv1.bias, スキップ
# vae.decoder.up.3.block.0.conv1.weight, スキップ
# vae.decoder.up.3.block.0.conv2.bias, スキップ
# vae.decoder.up.3.block.0.conv2.weight, スキップ
# vae.decoder.up.3.block.0.norm1.bias, スキップ
# vae.decoder.up.3.block.0.norm1.weight, スキップ
# vae.decoder.up.3.block.0.norm2.bias, スキップ
# vae.decoder.up.3.block.0.norm2.weight, スキップ
# vae.decoder.up.3.block.1.conv1.bias, スキップ
# vae.decoder.up.3.block.1.conv1.weight, スキップ
# vae.decoder.up.3.block.1.conv2.bias, スキップ
# vae.decoder.up.3.block.1.conv2.weight, スキップ
# vae.decoder.up.3.block.1.norm1.bias, スキップ
# vae.decoder.up.3.block.1.norm1.weight, スキップ
# vae.decoder.up.3.block.1.norm2.bias, スキップ
# vae.decoder.up.3.block.1.norm2.weight, スキップ
# vae.decoder.up.3.block.2.conv1.bias, スキップ
# vae.decoder.up.3.block.2.conv1.weight, スキップ
# vae.decoder.up.3.block.2.conv2.bias, スキップ
# vae.decoder.up.3.block.2.conv2.weight, スキップ
# vae.decoder.up.3.block.2.norm1.bias, スキップ
# vae.decoder.up.3.block.2.norm1.weight, スキップ
# vae.decoder.up.3.block.2.norm2.bias, スキップ
# vae.decoder.up.3.block.2.norm2.weight, スキップ
# vae.decoder.up.3.upsample.conv.bias, スキップ
# vae.decoder.up.3.upsample.conv.weight, スキップ
# vae.encoder.conv_in.bias, スキップ
# vae.encoder.conv_in.weight, スキップ
# vae.encoder.conv_out.bias, スキップ
# vae.encoder.conv_out.weight, スキップ
# vae.encoder.down.0.block.0.conv1.bias, スキップ
# vae.encoder.down.0.block.0.conv1.weight, スキップ
# vae.encoder.down.0.block.0.conv2.bias, スキップ
# vae.encoder.down.0.block.0.conv2.weight, スキップ
# vae.encoder.down.0.block.0.norm1.bias, スキップ
# vae.encoder.down.0.block.0.norm1.weight, スキップ
# vae.encoder.down.0.block.0.norm2.bias, スキップ
# vae.encoder.down.0.block.0.norm2.weight, スキップ
# vae.encoder.down.0.block.1.conv1.bias, スキップ
# vae.encoder.down.0.block.1.conv1.weight, スキップ
# vae.encoder.down.0.block.1.conv2.bias, スキップ
# vae.encoder.down.0.block.1.conv2.weight, スキップ
# vae.encoder.down.0.block.1.norm1.bias, スキップ
# vae.encoder.down.0.block.1.norm1.weight, スキップ
# vae.encoder.down.0.block.1.norm2.bias, スキップ
# vae.encoder.down.0.block.1.norm2.weight, スキップ
# vae.encoder.down.0.downsample.conv.bias, スキップ
# vae.encoder.down.0.downsample.conv.weight, スキップ
# vae.encoder.down.1.block.0.conv1.bias, スキップ
# vae.encoder.down.1.block.0.conv1.weight, スキップ
# vae.encoder.down.1.block.0.conv2.bias, スキップ
# vae.encoder.down.1.block.0.conv2.weight, スキップ
# vae.encoder.down.1.block.0.nin_shortcut.bias, スキップ
# vae.encoder.down.1.block.0.nin_shortcut.weight, スキップ
# vae.encoder.down.1.block.0.norm1.bias, スキップ
# vae.encoder.down.1.block.0.norm1.weight, スキップ
# vae.encoder.down.1.block.0.norm2.bias, スキップ
# vae.encoder.down.1.block.0.norm2.weight, スキップ
# vae.encoder.down.1.block.1.conv1.bias, スキップ
# vae.encoder.down.1.block.1.conv1.weight, スキップ
# vae.encoder.down.1.block.1.conv2.bias, スキップ
# vae.encoder.down.1.block.1.conv2.weight, スキップ
# vae.encoder.down.1.block.1.norm1.bias, スキップ
# vae.encoder.down.1.block.1.norm1.weight, スキップ
# vae.encoder.down.1.block.1.norm2.bias, スキップ
# vae.encoder.down.1.block.1.norm2.weight, スキップ
# vae.encoder.down.1.downsample.conv.bias, スキップ
# vae.encoder.down.1.downsample.conv.weight, スキップ
# vae.encoder.down.2.block.0.conv1.bias, スキップ
# vae.encoder.down.2.block.0.conv1.weight, スキップ
# vae.encoder.down.2.block.0.conv2.bias, スキップ
# vae.encoder.down.2.block.0.conv2.weight, スキップ
# vae.encoder.down.2.block.0.nin_shortcut.bias, スキップ
# vae.encoder.down.2.block.0.nin_shortcut.weight, スキップ
# vae.encoder.down.2.block.0.norm1.bias, スキップ
# vae.encoder.down.2.block.0.norm1.weight, スキップ
# vae.encoder.down.2.block.0.norm2.bias, スキップ
# vae.encoder.down.2.block.0.norm2.weight, スキップ
# vae.encoder.down.2.block.1.conv1.bias, スキップ
# vae.encoder.down.2.block.1.conv1.weight, スキップ
# vae.encoder.down.2.block.1.conv2.bias, スキップ
# vae.encoder.down.2.block.1.conv2.weight, スキップ
# vae.encoder.down.2.block.1.norm1.bias, スキップ
# vae.encoder.down.2.block.1.norm1.weight, スキップ
# vae.encoder.down.2.block.1.norm2.bias, スキップ
# vae.encoder.down.2.block.1.norm2.weight, スキップ
# vae.encoder.down.2.downsample.conv.bias, スキップ
# vae.encoder.down.2.downsample.conv.weight, スキップ
# vae.encoder.down.3.block.0.conv1.bias, スキップ
# vae.encoder.down.3.block.0.conv1.weight, スキップ
# vae.encoder.down.3.block.0.conv2.bias, スキップ
# vae.encoder.down.3.block.0.conv2.weight, スキップ
# vae.encoder.down.3.block.0.norm1.bias, スキップ
# vae.encoder.down.3.block.0.norm1.weight, スキップ
# vae.encoder.down.3.block.0.norm2.bias, スキップ
# vae.encoder.down.3.block.0.norm2.weight, スキップ
# vae.encoder.down.3.block.1.conv1.bias, スキップ
# vae.encoder.down.3.block.1.conv1.weight, スキップ
# vae.encoder.down.3.block.1.conv2.bias, スキップ
# vae.encoder.down.3.block.1.conv2.weight, スキップ
# vae.encoder.down.3.block.1.norm1.bias, スキップ
# vae.encoder.down.3.block.1.norm1.weight, スキップ
# vae.encoder.down.3.block.1.norm2.bias, スキップ
# vae.encoder.down.3.block.1.norm2.weight, スキップ
# vae.encoder.mid.attn_1.k.bias, スキップ
# vae.encoder.mid.attn_1.k.weight, スキップ
# vae.encoder.mid.attn_1.norm.bias, スキップ
# vae.encoder.mid.attn_1.norm.weight, スキップ
# vae.encoder.mid.attn_1.proj_out.bias, スキップ
# vae.encoder.mid.attn_1.proj_out.weight, スキップ
# vae.encoder.mid.attn_1.q.bias, スキップ
# vae.encoder.mid.attn_1.q.weight, スキップ
# vae.encoder.mid.attn_1.v.bias, スキップ
# vae.encoder.mid.attn_1.v.weight, スキップ
# vae.encoder.mid.block_1.conv1.bias, スキップ
# vae.encoder.mid.block_1.conv1.weight, スキップ
# vae.encoder.mid.block_1.conv2.bias, スキップ
# vae.encoder.mid.block_1.conv2.weight, スキップ
# vae.encoder.mid.block_1.norm1.bias, スキップ
# vae.encoder.mid.block_1.norm1.weight, スキップ
# vae.encoder.mid.block_1.norm2.bias, スキップ
# vae.encoder.mid.block_1.norm2.weight, スキップ
# vae.encoder.mid.block_2.conv1.bias, スキップ
# vae.encoder.mid.block_2.conv1.weight, スキップ
# vae.encoder.mid.block_2.conv2.bias, スキップ
# vae.encoder.mid.block_2.conv2.weight, スキップ
# vae.encoder.mid.block_2.norm1.bias, スキップ
# vae.encoder.mid.block_2.norm1.weight, スキップ
# vae.encoder.mid.block_2.norm2.bias, スキップ
# vae.encoder.mid.block_2.norm2.weight, スキップ
# vae.encoder.norm_out.bias, スキップ
# vae.encoder.norm_out.weight, スキップ
# vae.model_ema.decay, スキップ
# vae.model_ema.num_updates, スキップ
# vae.post_quant_conv.bias, スキップ
# vae.post_quant_conv.weight, スキップ
# vae.quant_conv.bias, スキップ
# vae.quant_conv.weight, スキップ
# /root/.cache/huggingface/hub/models--fal--AuraFlow-v0.3/snapshots/2cd8588f04c886002be4571697d84654a50e3af3/aura_flow_0.3.safetensors
# /content/drive/MyDrive/ComfyUI/models/checkpointsA/aura_flow_0.3-fp8.safetensors
# 5秒後にランタイムの接続を解除します。
